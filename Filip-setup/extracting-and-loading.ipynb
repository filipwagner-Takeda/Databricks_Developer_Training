# %%
# %sql
drop schema if exists hub_schema CASCADE;
drop schema if exists lake_schema CASCADE;
drop schema if exists raw_schema CASCADE;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS raw;
CREATE SCHEMA IF NOT EXISTS hub;
CREATE SCHEMA IF NOT EXISTS mart;

# %%
import pandas as pd
csv_to_load = ["customer", "product","sales"]
for csv_name in csv_to_load:
  df = pd.read_csv(f"https://raw.githubusercontent.com/VladisKliman/Databricks_Developer_Training/main/fixtures/{csv_name}.csv")
  spardk_df = spark.createDataFrame(df)
  spardk_df.write.format("delta").mode("overwrite").saveAsTable(f"raw.{csv_name}")

# %%
# %sql
SELECT * FROM raw.customer;
